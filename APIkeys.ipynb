# %%
import requests

url = "https://mashape-community-urban-dictionary.p.rapidapi.com/define"

querystring = {"term":"wat"}

headers = {
	"X-RapidAPI-Key": "320d5eb62dmshaed2e42df716490p186ad2jsn051350b52c89",
	"X-RapidAPI-Host": "mashape-community-urban-dictionary.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'list': [{'definition': 'The only [proper] [response] to something that makes absolutely [no sense].', 'permalink': 'http://wat.urbanup.com/3322419', 'thumbs_up': 3991, 'author': 'watwat', 'word': 'wat', 'defid': 3322419, 'current_vote': '', 'written_on': '2008-09-04T09:15:08.000Z', 'example': "1: If all the animals on the [equator] were capable of [flattery], Halloween and Easter would fall on the same day.\r\n2: wat\r\n\r\n1: Wow your cock is almost as big as my dad's.\r\n2: wat\r\n\r\n1: I accidentially a whole [coke bottle]\r\n2: You accidentially what?\r\n1: A whole coke bottle\r\n2: wat", 'thumbs_down': 443}, {'definition': 'Slang.  Indicates [confusion] or [a need] for [clarification].  Statement/question.', 'permalink': 'http://wat.urbanup.com/1308686', 'thumbs_up': 1218, 'author': 'stewpidwhytemayun', 'word': 'wat', 'defid': 1308686, 'current_vote': '', 'written_on': '2005-06-08T23:20:56.000Z', 'example': '1: "[lolz] Yea sex is great and everything but its way too overrated
# ...

# %%
import requests

url = "https://currencyconverter.p.rapidapi.com/availablecurrencies"

headers = {
	"X-RapidAPI-Key": "320d5eb62dmshaed2e42df716490p186ad2jsn051350b52c89",
	"X-RapidAPI-Host": "currencyconverter.p.rapidapi.com"
}

response = requests.get(url, headers=headers)

print(response.json())
# Out:
# {'messages': 'The API is unreachable, please contact the API provider', 'info': 'Your Client (working) ---> Gateway (working) ---> API (not working)'}

# %%
import requests

url = "https://numbersapi.p.rapidapi.com/6/21/date"

querystring = {"fragment":"true","json":"true"}

headers = {
	"X-RapidAPI-Key": "320d5eb62dmshaed2e42df716490p186ad2jsn051350b52c89",
	"X-RapidAPI-Host": "numbersapi.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'text': 'Admiral Ludwig von Reuter scuttles the German fleet in Scapa Flow, Orkney', 'year': 1919, 'number': 173, 'found': True, 'type': 'date'}

# %%
import requests

url = "https://wft-geo-db.p.rapidapi.com/v1/geo/adminDivisions"

headers = {
	"X-RapidAPI-Key": "320d5eb62dmshaed2e42df716490p186ad2jsn051350b52c89",
	"X-RapidAPI-Host": "wft-geo-db.p.rapidapi.com"
}

response = requests.get(url, headers=headers)

print(response.json())
# Out:
# {'data': [{'id': 3515514, 'wikiDataId': 'Q4117373', 'name': 'Al Mamzar', 'country': 'United Arab Emirates', 'countryCode': 'AE', 'region': 'Emirate of Dubai', 'regionCode': 'DU', 'regionWdId': 'Q613', 'latitude': 25.309469444, 'longitude': 55.342811111, 'population': 0}, {'id': 3671889, 'wikiDataId': 'Q1262899', 'name': 'Dubai Internet City', 'country': 'United Arab Emirates', 'countryCode': 'AE', 'region': 'Emirate of Dubai', 'regionCode': 'DU', 'regionWdId': 'Q613', 'latitude': 25.095, 'longitude': 55.16, 'population': 0}, {'id': 3386644, 'wikiDataId': 'Q3694483', 'name': 'Ab Band District', 'country': 'Afghanistan', 'countryCode': 'AF', 'region': 'Ghazni', 'regionCode': 'GHA', 'regionWdId': 'Q180415', 'latitude': 32.983, 'longitude': 67.967, 'population': 0}, {'id': 3339608, 'wikiDataId': 'Q2572213', 'name': 'Ab Kamari', 'country': 'Afghanistan', 'countryCode': 'AF', 'region': 'Badghis', 'regionCode': 'BDG', 'regionWdId': 'Q172052', 'latitude': 34.925, 'longitude': 62.901666666, '
# ...

# %%
import requests

url = "https://vegan-recipes-api.p.rapidapi.com/recipes/thewoksoflife"

headers = {
	"X-RapidAPI-Key": "89eec3fac7msh8ef52e62b39a544p111bafjsn7d33b5e1a73a",
	"X-RapidAPI-Host": "vegan-recipes-api.p.rapidapi.com"
}

response = requests.get(url, headers=headers)

print(response.json())
# Out:
# {'message': 'The following headers/query parameters are invalid', 'invalidHeaders': ['host', 'x-amzn-trace-id', 'x-forwarded-port', 'x-rapidapi-key', 'x-forwarded-proto', 'x-forwarded-for', 'user-agent', 'accept', 'x-rapidapi-host', 'accept-encoding'], 'invalidQueryParams': {}}

# %%
import requests

url = "https://crunchbase-crunchbase-v1.p.rapidapi.com/autocompletes"

querystring = {"query":"<REQUIRED>"}

headers = {
	"X-RapidAPI-Key": "b46037d014msh6fec74495d007efp1ed558jsnbc24544900d5",
	"X-RapidAPI-Host": "crunchbase-crunchbase-v1.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'count': 3817, 'entities': [{'facet_ids': ['rank', 'builtwith', 'company', 'siftery'], 'identifier': {'uuid': '145f7c52-b8d9-08b8-0db3-8a9d7db33869', 'value': 'required', 'image_id': 'v1457166268/tvu573ujzy5c77qbtwrz.png', 'permalink': 'required', 'entity_def_id': 'organization'}, 'short_description': 'required+ is a web design and development agency focused on interaction design, mobile and web applications, and WordPress.'}, {'facet_ids': ['company', 'rank', 'siftery'], 'identifier': {'uuid': '9d35ee24-0836-4599-814d-83d0dbee1f7d', 'value': 'required', 'image_id': 'vpohogcsqssapxyjt6im', 'permalink': 'required-1f7d', 'entity_def_id': 'organization'}, 'short_description': 'required is a digital agency for strategy, design and web development.'}, {'facet_ids': ['company', 'rank', 'aberdeen'], 'identifier': {'uuid': 'd67adb56-2632-44b5-a1bd-5845a9dd672d', 'value': 'required', 'permalink': 'required-672d', 'entity_def_id': 'organization'}, 'short_description': 'somethign'}, {'facet_id
# ...

# %%
import requests

url = "https://omgvamp-hearthstone-v1.p.rapidapi.com/info"

headers = {
	"X-RapidAPI-Key": "6e16379322mshcf65a4f68ff8c46p169906jsnc83c9d20fcbf",
	"X-RapidAPI-Host": "omgvamp-hearthstone-v1.p.rapidapi.com"
}

response = requests.get(url, headers=headers)

print(response.json())
# Out:
# {'patch': '28.6.3.195316', 'classes': ['Death Knight', 'Druid', 'Hunter', 'Mage', 'Paladin', 'Priest', 'Rogue', 'Shaman', 'Warlock', 'Warrior', 'Dream', 'Neutral', 'Whizbang', 'Demon Hunter'], 'sets': ['Basic', 'Classic', 'Hall of Fame', 'Missions', 'Demo', 'System', 'Slush', 'Promo', 'Naxxramas', 'Goblins vs Gnomes', 'Blackrock Mountain', 'The Grand Tournament', 'Credits', 'Hero Skins', 'Tavern Brawl', 'The League of Explorers', 'Whispers of the Old Gods', 'Whispers of the Old Gods', 'One Night in Karazhan', 'One Night in Karazhan', 'Mean Streets of Gadgetzan', 'Mean Streets of Gadgetzan', "Journey to Un'Goro", 'Knights of the Frozen Throne', 'Kobolds & Catacombs', 'The Witchwood', 'The Boomsday Project', "Rastakhan's Rumble", 'Rise of Shadows', 'Taverns of Time', 'Saviors of Uldum', 'Descent of Dragons', "Galakrond's Awakening", 'Ashes of Outland', 'Wild Event', 'Scholomance Academy', 'Battlegrounds', 'Demon Hunter Initiate', 'Madness at the Darkmoon Faire', 'Forged in the Barrens'
# ...

# %%
import requests

url = "https://matchilling-chuck-norris-jokes-v1.p.rapidapi.com/jokes/random"

headers = {
	"accept": "application/json",
	"X-RapidAPI-Key": "89eec3fac7msh8ef52e62b39a544p111bafjsn7d33b5e1a73a",
	"X-RapidAPI-Host": "matchilling-chuck-norris-jokes-v1.p.rapidapi.com"
}

response = requests.get(url, headers=headers)

print(response.json())
# Out:
# {'categories': [], 'created_at': '2020-01-05 13:42:30.480041', 'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png', 'id': 'JiERQMY4QM-swaA54r_I1g', 'updated_at': '2020-01-05 13:42:30.480041', 'url': 'https://api.chucknorris.io/jokes/JiERQMY4QM-swaA54r_I1g', 'value': 'Chuck Norris once helped an old lady across the street. When a car did not stop, he roundhoused kicked it thus creating the first mini. When the old lady thanked him he roundhoused kicked her for good measure.'}

# %%
import requests

url = "https://currency-exchange.p.rapidapi.com/exchange"

querystring = {"from":"SGD","to":"MYR","q":"1.0"}

headers = {
	"X-RapidAPI-Key": "89eec3fac7msh8ef52e62b39a544p111bafjsn7d33b5e1a73a",
	"X-RapidAPI-Host": "currency-exchange.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# 3.52877748

# %%
#seatgeek
import requests

url = "https://seatgeek-seatgeekcom.p.rapidapi.com/taxonomies"

headers = {
	"X-RapidAPI-Key": "518c2b8e3cmsh4da14faf282b637p1bf7e2jsnd94462d0592f",
	"X-RapidAPI-Host": "seatgeek-seatgeekcom.p.rapidapi.com"
}

response = requests.get(url, headers=headers)

print(response.json())
# Out:
# {'status': 403, 'message': 'Client is required - visit "https://seatgeek.com/account/develop"', 'errors': [{'message': 'Client is required - visit "https://seatgeek.com/account/develop"', 'code': 40307}], 'meta': {'status': 403}}

# %%
#thundercomb
import requests

url = "https://thundercomb-poetry-db-v1.p.rapidapi.com/title"

headers = {
	"X-RapidAPI-Key": "518c2b8e3cmsh4da14faf282b637p1bf7e2jsnd94462d0592f",
	"X-RapidAPI-Host": "thundercomb-poetry-db-v1.p.rapidapi.com"
}

response = requests.get(url, headers=headers)

print(response.json())
# Out:
# {'titles': [' Thoughts On The Works Of Providence', '"All Is Vanity, Saith the Preacher"', '"And the sins of the fathers shall be"', '"Arcturus" is his other name', '"By the Waters of Babylon."', '"De Gustibus--"', '"Faith" is a fine invention', '"Faithful to the end" Amended', '"Heaven" -- is what I cannot reach!', '"Heaven" has different Signs -- to me --', '"Heavenly Father" -- take to thee', '"Home"', '"Hope" is the thing with feathers', '"I have heard the sunset song of the birches,"', '"It was wrong to do this," said the angel', '"Lethe" in my flower,', '"Nature" is what we see --', '"The Lass With The Delicate Air"', "'Mighty Eagle'", "'Tis One by One -- the Father counts --", "'Tis moonlight, summer moonlight", "'Twas a long Parting -- but the time", "'Twas here my summer paused", "'Twas just this time, last year, I died.", "'Twas later when the summer went", "'Twould ease -- a Butterfly --", '101. Song—Composed in Spring', '115. The Farewell to the Brethren of St. James’s Lo
# ...

# %%
#moviesversel
import requests

url = "https://moviesverse1.p.rapidapi.com/get-trending-trailers"

headers = {
	"X-RapidAPI-Key": "518c2b8e3cmsh4da14faf282b637p1bf7e2jsnd94462d0592f",
	"X-RapidAPI-Host": "moviesverse1.p.rapidapi.com"
}

response = requests.get(url, headers=headers)

print(response.json())
# Out:
# {'trailers': [{'image': 'https://m.media-amazon.com/images/M/MV5BNmEzOTE4NzktYWU4Ny00YTQ3LTlhNDEtMjNmNTg3NTRkMzNhXkEyXkFqcGdeQXVyMTMzNzIyNDc1.300_.jpg', 'trailerLength': '2:47', 'title': 'Damsel', 'releaseDate': 'March 8, 2024', 'videoLink': 'https://www.imdb.com//title/tt13452446/?ref_=vi_tr_tr_tt_0'}, {'image': 'https://m.media-amazon.com/images/M/MV5BOTE5ZTY3NzktYmVkNS00NzRhLWI3YzUtNTA3MDVkYmIzMGVmXkEyXkFqcGdeQXVyMjYwNDA2MDE@.300_.jpg', 'trailerLength': '2:10', 'title': 'The Watchers', 'releaseDate': 'June 14, 2024', 'videoLink': 'https://www.imdb.com//title/tt26736843/?ref_=vi_tr_tr_tt_1'}, {'image': 'https://m.media-amazon.com/images/M/MV5BOWZmOTM5YmMtNjliMi00OGRkLWIwNGUtNDI2NTE3NzZmMDdmXkEyXkFqcGdeQXVyMTUzMTg2ODkz.300_.jpg', 'trailerLength': '2:44', 'title': 'Borderlands', 'releaseDate': 'August 9, 2024', 'videoLink': 'https://www.imdb.com//title/tt4978420/?ref_=vi_tr_tr_tt_2'}, {'image': 'https://m.media-amazon.com/images/M/MV5BZDY0YzI0OTctYjVhYy00MTVhLWE0NTgtYTRmYTBmOTE3YTViX
# ...

# %%
#Spotify Downloader
import requests

url = "https://spotify-downloader6.p.rapidapi.com/spotify"

querystring = {"spotifyUrl":"https://open.spotify.com/track/6XW7SptZnrg1sdtYQGxcOS?si=3bf7b3822ca14a25"}

headers = {
	"X-RapidAPI-Key": "518c2b8e3cmsh4da14faf282b637p1bf7e2jsnd94462d0592f",
	"X-RapidAPI-Host": "spotify-downloader6.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'type': 'track', 'title': 'Tu Kuja Mann Kuja', 'artist': ['Noorul Huda'], 'cover': 'https://i.scdn.co/image/ab67616d0000b27393cfd6073e26a814d4f3169f', 'download_link': 'https://spotifymate.com/dl?url=aHR0cHM6Ly9tZGVsdGEuMTIzdG9reW8ueHl6L2dldC5waHAvYy8wMy9wTG5TY1NzWFBfRS5tcDM_Y2lkPU1tRXdNVG8wWmpnNll6QXhNam96T1dKbE9qb3hmRTVCZkVSRiZoPWN5SFBmX1NIR3otbEw0Z09Hb2t0bXcmcz0xNzA5NDQ2OTU0Jm49VHUlMjBLdWphJTIwTWFubiUyMEt1amEmY2lkMj1PREV1TVRjeExqSTVMakUyZkU1TWZGSkpRVVUzUXpNd01UYzVNa0U0TWpndw&title=VHUgS3VqYSBNYW5uIEt1amEgLSBOb29ydWwgSHVkYQ&type=mp3'}

# %%
#scoring tables
import requests

url = "https://scoring-tables-api.p.rapidapi.com/marks/men/1400"

headers = {
	"X-RapidAPI-Key": "518c2b8e3cmsh4da14faf282b637p1bf7e2jsnd94462d0592f",
	"X-RapidAPI-Host": "scoring-tables-api.p.rapidapi.com"
}

response = requests.get(url, headers=headers)

print(response.json())
# Out:
# {'_id': 1400, 'points': 1400, '100m': 9.46, '200m': None, '400m': 41.97, '100mH': None, '110mH': 12.28, '400mH': 44.86, '4x100m': 35.84, '4x400m': 167.49, '800m': 97.91, '1600m': 215.28, '3200m': 458.54, 'HJ': None, 'PV': 6.48, 'LJ': None, 'TJ': 19.19, 'SP': 24.66, 'DT': 78.39}

# %%
import requests

url = "https://inteltech.p.rapidapi.com/credit.php"

payload = {
	"username": "temp-idk-test-dynamic",
	"key": "1B490066-EA03-E39A-A18C-C4868E45CFAE"
}
headers = {
	"content-type": "application/x-www-form-urlencoded",
	"X-RapidAPI-Key": "518c2b8e3cmsh4da14faf282b637p1bf7e2jsnd94462d0592f",
	"X-RapidAPI-Host": "inteltech.p.rapidapi.com"
}

response = requests.post(url, data=payload, headers=headers)

print(response.json())
# Out:
# 2022

# %%
import requests

url = "https://uncovered-treasure-v1.p.rapidapi.com/topics"

headers = {
	"X-RapidAPI-Key": "518c2b8e3cmsh4da14faf282b637p1bf7e2jsnd94462d0592f",
	"X-RapidAPI-Host": "uncovered-treasure-v1.p.rapidapi.com"
}

response = requests.get(url, headers=headers)

print(response.json())
# Out:
# {'results': [None, " God's Word", ' Leaders', ' Scriptures', 'Abandonment', 'Abhor Evil', 'Abhor, abhor evil', 'Abide', 'Abide In Christ', 'Abide in Christ', 'Ability', 'Ability, righteous judgment', 'Abomination', 'Abomination, God', 'Abundant', 'Abundant Life', 'Abuse', 'Abuse of Grace', 'Accept', 'Acceptable', 'Accidental Death', 'Accountability', 'Accountable', 'Accountable, God, responsible, way', 'Accusations', 'Accused', 'Accuser', 'Acknowledge God', 'Act, God', 'Actions', 'Admit Sins', 'Adoption', 'Adultery', 'Adversity', 'Advertise', 'Affects', 'Afraid', 'Afraid, confidence in God, trust God', 'Against God', 'Agony', 'Agony, heart for God', 'Alert, falling, temptation, disciple', 'Aliens', 'Almighty God', 'Amazing', 'Anguish', 'Anguish, sins', 'Animals', 'Annul', 'Anointing', 'Answered Prayer', 'Answered Prayers', 'Answered prayer', 'Answered prayer, disciples', 'Answered prayers, testimony', 'Answers To Prayer', 'Anti-God', 'Apostasy', 'Appeal, meekness', 'Appeals', 'Appear
# ...

# %%
import requests

url = "https://marvel-vs-capcom-2.p.rapidapi.com/characters/Akuma/moves"

headers = {
	"X-RapidAPI-Key": "518c2b8e3cmsh4da14faf282b637p1bf7e2jsnd94462d0592f",
	"X-RapidAPI-Host": "marvel-vs-capcom-2.p.rapidapi.com"
}

response = requests.get(url, headers=headers)

print(response.json())
# Out:
# [{'character_name': 'Cable', 'move_name': 'Viper Beam', 'image': '/images/Move_Images/Cable/Viper Beam.PNG'}, {'character_name': 'Cable', 'move_name': 'Scimitar', 'image': '/images/Move_Images/Cable/Scimitar.PNG'}, {'character_name': 'Cable', 'move_name': 'Elec-Trap', 'image': '/images/Move_Images/Cable/Elec-Trap.PNG'}, {'character_name': 'Cable', 'move_name': 'Crackdown', 'image': '/images/Move_Images/Cable/Crackdown.PNG'}, {'character_name': 'Cable', 'move_name': 'Psy-Charge', 'image': '/images/Move_Images/Cable/Psy-Charge.PNG'}, {'character_name': 'Cable', 'move_name': 'Hyper Viper', 'image': '/images/Move_Images/Cable/Hyper Viper.PNG'}, {'character_name': 'Cable', 'move_name': 'Time Flip', 'image': '/images/Move_Images/Cable/Time Flip.PNG'}]

# %%
import requests

url = "https://pokedex2.p.rapidapi.com/pokedex/uk/pikachu"

headers = {
	"X-RapidAPI-Key": "89eec3fac7msh8ef52e62b39a544p111bafjsn7d33b5e1a73a",
	"X-RapidAPI-Host": "pokedex2.p.rapidapi.com"
}

response = requests.get(url, headers=headers)

print(response.json())
# Out:
# [{'name': 'Pikachu', 'slug': 'pikachu', 'thumbnailimage': 'https://assets.pokemon.com/assets/cms2/img/pokedex/full/025.png', 'thumbnailalttext': 'Pikachu', 'height': '0.4 m', 'weight': '6.0 kg', 'sex': ['male', 'female'], 'category': 'Mouse', 'abilities': 'Static', 'id': 25, 'type': ['Electric'], 'weaknesses': ['Ground']}, {'name': 'Gigantamax Pikachu', 'slug': 'gigantamax_pikachu', 'thumbnailimage': 'https://assets.pokemon.com/assets/cms2/img/pokedex/full/025_f2.png', 'thumbnailalttext': 'Gigantamax Pikachu', 'height': '>21.0 m', 'weight': '???.? kg', 'sex': ['male', 'female'], 'category': 'Mouse', 'abilities': 'Static', 'id': 25, 'type': ['Electric'], 'weaknesses': ['Ground']}]

# %%
#google translator
import requests

url = "https://google-translate1.p.rapidapi.com/language/translate/v2"

payload = {
	"q": "Hello, world!",
	"target": "es",
	"source": "en"
}
headers = {
	"content-type": "application/x-www-form-urlencoded",
	"Accept-Encoding": "application/gzip",
	"X-RapidAPI-Key": "80e81a7eb6msh6098ce9acfb1849p1e804bjsnda3cc8f14197",
	"X-RapidAPI-Host": "google-translate1.p.rapidapi.com"
}

response = requests.post(url, data=payload, headers=headers)

print(response.json())
# Out:
# {'data': {'translations': [{'translatedText': '¡Hola Mundo!'}]}}

# %%
import requests

url = "https://apidojo-yahoo-finance-v1.p.rapidapi.com/auto-complete"

querystring = {"q":"tesla","region":"US"}

headers = {
	"X-RapidAPI-Key": "a261c226cemshd292f6375169e55p1b2a24jsna6dab3bf0c37",
	"X-RapidAPI-Host": "apidojo-yahoo-finance-v1.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'explains': [], 'count': 15, 'quotes': [{'exchange': 'NMS', 'shortname': 'Tesla, Inc.', 'quoteType': 'EQUITY', 'symbol': 'TSLA', 'index': 'quotes', 'score': 73745.0, 'typeDisp': 'Equity', 'longname': 'Tesla, Inc.', 'exchDisp': 'NASDAQ', 'sector': 'Consumer Cyclical', 'sectorDisp': 'Consumer Cyclical', 'industry': 'Auto Manufacturers', 'industryDisp': 'Auto Manufacturers', 'dispSecIndFlag': True, 'isYahooFinance': True}, {'exchange': 'GER', 'shortname': 'TESLA INC. DL -,001', 'quoteType': 'EQUITY', 'symbol': 'TL0.DE', 'index': 'quotes', 'score': 20093.0, 'typeDisp': 'Equity', 'longname': 'Tesla, Inc.', 'exchDisp': 'XETRA', 'sector': 'Consumer Cyclical', 'sectorDisp': 'Consumer Cyclical', 'industry': 'Auto Manufacturers', 'industryDisp': 'Auto Manufacturers', 'isYahooFinance': True}, {'exchange': 'NEO', 'shortname': 'TESLA, INC. CDR (CAD HEDGED)', 'quoteType': 'EQUITY', 'symbol': 'TSLA.NE', 'index': 'quotes', 'score': 20061.0, 'typeDisp': 'Equity', 'longname': 'Tesla, Inc.', 'exchDisp
# ...

# %%
#jobsearch
import requests

url = "https://jsearch.p.rapidapi.com/search"

querystring = {"query":"Python developer in Texas, USA","page":"1","num_pages":"1"}

headers = {
	"X-RapidAPI-Key": "80e81a7eb6msh6098ce9acfb1849p1e804bjsnda3cc8f14197",
	"X-RapidAPI-Host": "jsearch.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'status': 'OK', 'request_id': 'e25d75e4-2841-4771-8eec-bac6e72603df', 'parameters': {'query': 'python developer in texas, usa', 'page': 1, 'num_pages': 1}, 'data': [{'job_id': 'rfFwhpz3nvdqB0TSAAAAAA==', 'employer_name': 'Ascendion', 'employer_logo': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcT8i49TxmypL921gwSrXCigLk762K1u2Qu9yW0x&s=0', 'employer_website': 'http://www.ascendion.com', 'employer_company_type': None, 'job_publisher': 'Recruit.net', 'job_employment_type': 'FULLTIME', 'job_title': 'Python Developer', 'job_apply_link': 'https://www.recruit.net/job/python-developer-jobs/B0C3BAD703F0FFC3', 'job_apply_is_direct': False, 'job_apply_quality_score': 0.4342, 'apply_options': [{'publisher': 'Recruit.net', 'apply_link': 'https://www.recruit.net/job/python-developer-jobs/B0C3BAD703F0FFC3', 'is_direct': False}], 'job_description': 'About Ascendion\n\nAscendion is a full-service digital engineering solutions company. We make and manage software platforms and products that
# ...

# %%
import requests

url = "https://odds.p.rapidapi.com/v4/sports"

querystring = {"all":"true"}

headers = {
	"X-RapidAPI-Key": "a261c226cemshd292f6375169e55p1b2a24jsna6dab3bf0c37",
	"X-RapidAPI-Host": "odds.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# [{'key': 'americanfootball_cfl', 'group': 'American Football', 'title': 'CFL', 'description': 'Canadian Football League', 'active': False, 'has_outrights': False}, {'key': 'americanfootball_ncaaf', 'group': 'American Football', 'title': 'NCAAF', 'description': 'US College Football', 'active': True, 'has_outrights': False}, {'key': 'americanfootball_ncaaf_championship_winner', 'group': 'American Football', 'title': 'NCAAF Championship Winner', 'description': 'US College Football Championship Winner', 'active': True, 'has_outrights': True}, {'key': 'americanfootball_nfl', 'group': 'American Football', 'title': 'NFL', 'description': 'US Football', 'active': False, 'has_outrights': False}, {'key': 'americanfootball_nfl_preseason', 'group': 'American Football', 'title': 'NFL Preseason', 'description': 'US Football', 'active': False, 'has_outrights': False}, {'key': 'americanfootball_nfl_super_bowl_winner', 'group': 'American Football', 'title': 'NFL Super Bowl Winner', 'description': 'Sup
# ...

# %%
import requests

url = "https://cloudlabs-text-to-speech.p.rapidapi.com/languages"

headers = {
	"X-RapidAPI-Key": "914fe74234mshc1ef292e8a3abe7p1824c5jsn6b4057a4b139",
	"X-RapidAPI-Host": "cloudlabs-text-to-speech.p.rapidapi.com"
}

response = requests.get(url, headers=headers)

print(response.json())
# Out:
# {'message': 'You have exceeded the MONTHLY quota for Requests on your current plan, BASIC. Upgrade your plan at https://rapidapi.com/cloudlabs-dev/api/cloudlabs-text-to-speech'}

# %%
#movie database
import requests

url = "https://moviesdatabase.p.rapidapi.com/titles/series/%7BseriesId%7D"

headers = {
	"X-RapidAPI-Key": "80e81a7eb6msh6098ce9acfb1849p1e804bjsnda3cc8f14197",
	"X-RapidAPI-Host": "moviesdatabase.p.rapidapi.com"
}

response = requests.get(url, headers=headers)

print(response.json())
# Out:
# {'results': []}

# %%
import requests

url = "https://transloc-api-1-2.p.rapidapi.com/agencies.json"

querystring = {"callback":"call","geo_area":"35.80176,-78.64347|35.78061,-78.68218","agencies":"12"}

headers = {
	"X-RapidAPI-Key": "a261c226cemshd292f6375169e55p1b2a24jsna6dab3bf0c37",
	"X-RapidAPI-Host": "transloc-api-1-2.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'rate_limit': 1, 'expires_in': 300, 'api_latest_version': '1.2', 'generated_on': '2024-03-03T05:03:40+00:00', 'data': [], 'api_version': '1.2'}

# %%
import requests

url = "https://realtor.p.rapidapi.com/locations/v2/auto-complete"

querystring = {"input":"new york","limit":"10"}

headers = {
	"X-RapidAPI-Key": "a261c226cemshd292f6375169e55p1b2a24jsna6dab3bf0c37",
	"X-RapidAPI-Host": "realtor.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'meta': {'version': '0.108.0.0.108.0.2154.v108', 'es_took': 14, 'es_total_hits': 5642}, 'autocomplete': [{'area_type': 'state', '_id': 'state:ny', '_score': 36035.56, 'state': 'New York', 'state_code': 'NY', 'country': 'USA', 'centroid': {'lon': -75.5965453188093, 'lat': 42.9212421566579}, 'slug_id': 'New-York', 'geo_id': '7a9bffcb-e43c-5cdd-89ff-08ead6d8225d'}, {'area_type': 'city', '_id': 'city:ny_new-york', '_score': 34.65644, 'city': 'New York', 'state_code': 'NY', 'counties': [{'name': 'Queens', 'fips': '36081', 'state_code': 'NY'}, {'name': 'Kings', 'fips': '36047', 'state_code': 'NY'}, {'name': 'Richmond', 'fips': '36085', 'state_code': 'NY'}, {'name': 'Bronx', 'fips': '36005', 'state_code': 'NY'}, {'name': 'New York', 'fips': '36061', 'state_code': 'NY'}], 'country': 'USA', 'centroid': {'lon': -73.9386968, 'lat': 40.6634682}, 'slug_id': 'New-York_NY', 'geo_id': 'a5cac742-26a8-5870-b961-472ec6f9d824', 'county_needed_for_uniq': False}, {'area_type': 'city', '_id': 'city:ny_man
# ...

# %%
import requests

url = "https://local-business-data.p.rapidapi.com/search"

querystring = {"query":"Hotels in San Francisco, USA","limit":"20","lat":"37.359428","lng":"-121.925337","zoom":"13","language":"en","region":"us"}

headers = {
	"X-RapidAPI-Key": "14f3984d75msh7d4a82c8c6cc6f6p19aa1bjsn753249fd86d3",
	"X-RapidAPI-Host": "local-business-data.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'status': 'OK', 'request_id': '71d84223-5b00-4390-a28f-54171201ca80', 'parameters': {'query': 'Hotels in San Francisco, USA', 'language': 'en', 'region': 'us', 'lat': 37.359428, 'lng': -121.925337, 'zoom': 13, 'limit': 20, 'offset': 0}, 'data': [{'business_id': '0x8085808b287f3b3b:0xa49802f84f7ddb35', 'google_id': '0x8085808b287f3b3b:0xa49802f84f7ddb35', 'place_id': 'ChIJOzt_KIuAhYARNdt9T_gCmKQ', 'google_mid': '/m/06618ms', 'phone_number': '+14154336600', 'name': 'Hilton San Francisco Financial District', 'latitude': 37.7952284, 'longitude': -122.40407289999999, 'full_address': 'Hilton San Francisco Financial District, 750 Kearny St, San Francisco, CA 94108', 'review_count': 4981, 'rating': 3.9, 'timezone': 'America/Los_Angeles', 'working_hours': None, 'website': 'https://www.hilton.com/en/hotels/sfofdhf-hilton-san-francisco-financial-district/?SEO_id=GMB-AMER-HH-SFOFDHF&y_source=1_MTIyMDk1Ni03MTUtbG9jYXRpb24ud2Vic2l0ZQ%3D%3D', 'verified': True, 'place_link': 'https://www.google.com
# ...

# %%
import requests

url = "https://sales-tax-calculator.p.rapidapi.com/rates"

payload = {
	"city": "Menlo Park",
	"state": "CA",
	"street": "1 Hacker Way",
	"zip": "94025"
}
headers = {
	"content-type": "application/json",
	"X-RapidAPI-Key": "14f3984d75msh7d4a82c8c6cc6f6p19aa1bjsn753249fd86d3",
	"X-RapidAPI-Host": "sales-tax-calculator.p.rapidapi.com"
}

response = requests.post(url, json=payload, headers=headers)

print(response.json())
# Out:
# {'tax_on_shipping': False, 'tax_rate': 9.375}

# %%
import requests

url = "https://sms77io.p.rapidapi.com/analytics"

querystring = {"p":"<REQUIRED>","label":"all","subaccounts":"only_main"}

headers = {
	"X-RapidAPI-Key": "d5287a7b0amshf2f231f966aacc6p100c77jsn2fe312f983ec",
	"X-RapidAPI-Host": "sms77io.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# 900

# %%
import requests

url = "https://jikan1.p.rapidapi.com/meta/requests/anime/today"

headers = {
	"X-RapidAPI-Key": "90fb2b0d3fmsh934a77e33739f83p146b87jsn6ca0847ab1d0",
	"X-RapidAPI-Host": "jikan1.p.rapidapi.com"
}

response = requests.get(url, headers=headers)

print(response.json())
# Out:
# {'status': 410, 'type': 'BadResponseException', 'message': 'v3 has been discontinued. For more information visit https://bit.ly/jikan-v3-deprecation', 'upgrade': 'Please upgrade to v4: https://docs.api.jikan.moe/'}

# %%
import requests

url = "https://free-to-play-games-database.p.rapidapi.com/api/filter"

querystring = {"tag":"3d.mmorpg.fantasy.pvp","platform":"pc"}

headers = {
	"X-RapidAPI-Key": "90fb2b0d3fmsh934a77e33739f83p146b87jsn6ca0847ab1d0",
	"X-RapidAPI-Host": "free-to-play-games-database.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# [{'id': 6, 'title': 'Blade and Soul', 'thumbnail': 'https://www.freetogame.com/g/6/thumbnail.jpg', 'short_description': 'A free-to-play martial arts MMORPG that tasks players with learning combination attacks.', 'game_url': 'https://www.freetogame.com/open/blade-and-soul', 'genre': 'MMORPG', 'platform': 'PC (Windows)', 'publisher': 'NCSoft', 'developer': 'NCSoft', 'release_date': '2016-01-19', 'freetogame_profile_url': 'https://www.freetogame.com/blade-and-soul'}, {'id': 8, 'title': 'Trove', 'thumbnail': 'https://www.freetogame.com/g/8/thumbnail.jpg', 'short_description': 'A free to play Sandbox massively multiplayer online role-playing game! ', 'game_url': 'https://www.freetogame.com/open/trove', 'genre': 'MMORPG', 'platform': 'PC (Windows)', 'publisher': 'Trion Worlds', 'developer': 'Trion Worlds', 'release_date': '2015-07-09', 'freetogame_profile_url': 'https://www.freetogame.com/trove'}, {'id': 10, 'title': 'ArcheAge', 'thumbnail': 'https://www.freetogame.com/g/10/thumbnail.jpg',
# ...

# %%
import requests

url = "https://covid-193.p.rapidapi.com/countries"

headers = {
	"X-RapidAPI-Key": "d5287a7b0amshf2f231f966aacc6p100c77jsn2fe312f983ec",
	"X-RapidAPI-Host": "covid-193.p.rapidapi.com"
}

response = requests.get(url, headers=headers)

print(response.json())
# Out:
# {'get': 'countries', 'parameters': [], 'errors': [], 'results': 231, 'response': ['Afghanistan', 'Albania', 'Algeria', 'Andorra', 'Angola', 'Anguilla', 'Antigua-and-Barbuda', 'Argentina', 'Armenia', 'Aruba', 'Australia', 'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin', 'Bermuda', 'Bhutan', 'Bolivia', 'Bosnia-and-Herzegovina', 'Botswana', 'Brazil', 'British-Virgin-Islands', 'Brunei', 'Bulgaria', 'Burkina-Faso', 'Burundi', 'Cabo-Verde', 'Cambodia', 'Cameroon', 'Canada', 'CAR', 'Caribbean-Netherlands', 'Cayman-Islands', 'Chad', 'Channel-Islands', 'Chile', 'China', 'Colombia', 'Comoros', 'Congo', 'Cook-Islands', 'Costa-Rica', 'Croatia', 'Cuba', 'Cura&ccedil;ao', 'Cyprus', 'Czechia', 'Denmark', 'Diamond-Princess', 'Djibouti', 'Dominica', 'Dominican-Republic', 'DPRK', 'DRC', 'Ecuador', 'Egypt', 'El-Salvador', 'Equatorial-Guinea', 'Eritrea', 'Estonia', 'Eswatini', 'Ethiopia', 'Faeroe-Islands', 'Falkland-Islands', 'Fiji', 'Finl
# ...
