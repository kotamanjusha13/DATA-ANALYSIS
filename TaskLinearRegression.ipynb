# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Sample data
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]

# Create a Pandas DataFrame
data = pd.DataFrame({'x': x, 'y': y})

# Create a Seaborn linear plot
sns.lmplot(x='x', y='y', data=data, fit_reg=True)


# Show the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate sample data
np.random.seed(0)
num_points = 100

# Generate random data points for class A (above the line)
class_A_x = np.random.uniform(0, 10, num_points)
class_A_y = 0.4 * class_A_x + np.random.normal(3, 1, num_points)

# Generate random data points for class B (below the line)
class_B_x = np.random.uniform(0, 10, num_points)
class_B_y = 0.4 * class_B_x + np.random.normal(-2, 1, num_points)

# Plot the data
plt.figure(figsize=(8, 6))

# Plot points for class A (dots)
plt.scatter(class_A_x, class_A_y, color='blue', marker='o', label='Class A')

# Plot points for class B (squares)
plt.scatter(class_B_x, class_B_y, color='red', marker='s', label='Class B')
x_line = np.linspace(0, 10, 100)
y_line = 0.4 * x_line + 1.5
plt.plot(x_line, y_line, color='black', linestyle='--', label='Separating Line')


plt.xlabel('X')
plt.ylabel('Y')
plt.title('Linear Graph with Two Classes')
plt.legend()
plt.grid(True)
plt.show()

# %%
from sklearn.linear_model import LinearRegression
LR=LinearRegression()
t=[[5],[7],[10],[12],[15],[20]]
m=[40,80,120,200,240,250]
LR.fit(t,m)
LR.predict([[6]])
# Out:
# array([71.6722408])

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
data_true=pd.read_csv("/content/Amazon.csv")
data_fake=pd.read_csv("/content/twitter.csv")

# %%
data_true.head(5)
# Out:
#    1 perfect size for digital camcorder, good protection, quality
# 0  1  im pushing hard to hit an average of 10k/month...
# 1  1  not the best known movie but an ingenious plot...
# 2  1                            i just got rick rolled.
# 3  1                                  really good show.
# 4  1  one cannot put it down, it totally sweeps you ...

# %%
data_fake.head(5)
# Out:
#    0                      god i hate waiting around #fb
# 0  0                                  wanted to love it
# 1  0                             eat"less", lose weight
# 2  0                  good book -- but not this edition
# 3  0  i'll be there sunday night up until thursday m...
# 4  0                              cheap! cheap! cheap!!

# %%
data_true.tail(5)
# Out:
#     1 perfect size for digital camcorder, good protection, quality
# 54  1                             this cd is the truth!!
# 55  1                           the most effective brief
# 56  1  a different coping mechanism set in an interes...
# 57  1       the loss, the finding of the authentic self.
# 58  1  ohdid i mention my boy lost 2nite =( oh well, ...

# %%
data_fake.tail(5)
# Out:
#     0                      god i hate waiting around #fb
# 55  0  nope...i'll be up in lake tahoe at that time.y...
# 56  0                                crappy dvd transfer
# 57  0  these never close properly. very often i have ...
# 58  0                                             router
# 59  0  my man leaving me to go ny for the nba draft.....

# %%
data_true.shape
data_fake.shape
# Out:
# (60, 2)

# %%
import numpy as np
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
data_true["class"]=1
data_fake["class"]=0

# %%
data_true_manual_testing=data_true.tail(10)
data_true.tail(10)
for i in range(59,59,-1):
  data_true.drop([i],axis=0,inplace=True)

data_fake_manual_testing=data_true.tail(10)
data_fake.tail(10)
for i in range(59,59,-1):
  data_fake.drop([i],axis=0,inplace=True)

# %%
data_manual_testing = pd.concat([data_fake_manual_testing, data_true_manual_testing], axis=0)
data_manual_testing.to_csv("manual_testing.csv ")

# %%
data_merge = pd.concat([data_fake,data_true],axis=0)
data_merge.head(10)#displaying first 10 values after above operation
# Out:
#      0                      god i hate waiting around #fb  class   1  \
# 0  0.0                                  wanted to love it      0 NaN
# 1  0.0                             eat"less", lose weight      0 NaN
# 2  0.0                  good book -- but not this edition      0 NaN
# 3  0.0  i'll be there sunday night up until thursday m...      0 NaN
# 4  0.0                              cheap! cheap! cheap!!      0 NaN
# 5  0.0                                       use lansinoh      0 NaN
# 6  0.0                                    snow-white bomb      0 NaN
# 7  0.0  life suckz. my mom got this huge sat preparati...      0 NaN
# 8  0.0  damn! damn! damn! it's thunder storming. rain,...      0 NaN
# 9  0.0                 away to do this revision now.. bye      0 NaN
#
#   perfect size for digital camcorder, good protection, quality
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN

# %%
print(data_merge.groupby(['god i hate waiting around #fb'])['perfect size for digital camcorder, good protection, quality'].count())
data_merge.groupby(['god i hate waiting around #fb'])['perfect size for digital camcorder, good protection, quality'].count().plot(kind="bar")
plt.title(" god i hate waiting around #fb vs perfect size for digital camcorder, good protection, quality ",size=20)
plt.xlabel(" god i hate waiting around #fb",size=20)
plt.ylabel(" perfect size for digital camcorder, good protection, quality",size=20)
plt.show()
# Out:
# god i hate waiting around #fb
# a c- thriller                                                                                                                                         0
# ah bridge to terabethia sucksss.                                                                                                                      0
# attempting to make money on am unspeakable horror.                                                                                                    0
# away to do this revision now.. bye                                                                                                                    0
# back in the land of the living, but alas, have head in work!                                                                                          0
# bland and awkward prose                                                                                                                               0
# buy this dvd if your desperate to look at half naked men                                                                                              0
# cheap! cheap! cheap!!                                                                                                                                 0
# crappy dvd transfer                                                                                                                                   0
# damn! damn! damn! it's thunder storming. rain, rain go away                                                                                           0
# do not buy the mr. coffee ft series                                                                                                                   0
# does not have movies advertised on box!                                                                                                               0
# dude this movie is stupid                                                                                                                             0
# eat"less", lose weight                                                                                                                                0
# ep is driving me insane                                                                                                                               0
# excessive speed kills- especially in bach's cantatas                                                                                                  0
# fraud and dishonesty from top to bottom                                                                                                               0
# good book -- but not this edition                                                                                                                     0
# good if compared w/ other van hagar albums                                                                                                            0
# great for the one-eared. not so much for anyone else.                                                                                                 0
# how do you get $6.49 ($2.70 / oz) on a .63 product?                                                                                                   0
# i am so damn itchy! make it go away!                                                                                                                  0
# i hate filling in forms online for car insurance.. i cant think of anything more tedious!!!                                                           0
# i have another version of auralog that was also a waste of money.                                                                                     0
# i would not purchase this item.                                                                                                                       0
# i'll be there sunday night up until thursday morning... heard it is rainy.at least i'll be used to it! ;)                                             0
# info incorrect on amazon web sight!!!!                                                                                                                0
# it's been 3 weeks since your last video.                                                                                                              0
# just woke up from my nap, i can't believe i missed jibbs on 106 lol                                                                                   0
# learn to swim your drowning!                                                                                                                          0
# lies lies lies through and through                                                                                                                    0
# life suckz. my mom got this huge sat preparation book and she's going to make me ruin my whole summer by finishing it.                                0
# looked inside there, couldn't find it.                                                                                                                0
# my man leaving me to go ny for the nba draft...keep me busy twitter...                                                                                0
# nope...i'll be up in lake tahoe at that time.you need to come see me in san francisco!                                                                0
# not john's best work!                                                                                                                                 0
# pure junk don't waste your money                                                                                                                      0
# put your shoes back on robert                                                                                                                         0
# remote control and optical audo plusess don't outweight frequent resync issues                                                                        0
# router                                                                                                                                                0
# size 5 causes pimple like bumps....                                                                                                                   0
# snow-white bomb                                                                                                                                       0
# sounds great...easily breaks!!!                                                                                                                       0
# speader review                                                                                                                                        0
# spend the money on the 1.4                                                                                                                            0
# spicy world fennel seeds                                                                                                                              0
# starrett prosite                                                                                                                                      0
# strawberry milkshake for me ;-) ... wish i had some now lol                                                                                           0
# stuck at home on a friday night..sucks my moms car is getting fixed which causes me not to have my car                                                0
# terrible, a disgrace                                                                                                                                  0
# the house on sidney island was waaaaay to quiet without max's raspy breathing                                                                         0
# the price makes no sense                                                                                                                              0
# the tempest,a confusingly great story by william shakespeare                                                                                          0
# these never close properly. very often i have found that the seams have opened despite the zipper not having moved.                                   0
# this tutu says it is for 3-8 year olds. well, it is extremely small. is probably a 2t. will fit most three year olds but no older/bigger children.    0
# thrustmaster rip-off                                                                                                                                  0
# use lansinoh                                                                                                                                          0
# wanted to love it                                                                                                                                     0
# where are anne and gil?                                                                                                                               0
# wrong grill shipped                                                                                                                                   0
# Name: perfect size for digital camcorder, good protection, quality, dtype: int64

# %%
data = data_merge.drop(["perfect size for digital camcorder, good protection, quality"], axis=1)
data.head(10) #displaying remaining dataset
# Out:
#      0                      god i hate waiting around #fb  class   1
# 0  0.0                                  wanted to love it      0 NaN
# 1  0.0                             eat"less", lose weight      0 NaN
# 2  0.0                  good book -- but not this edition      0 NaN
# 3  0.0  i'll be there sunday night up until thursday m...      0 NaN
# 4  0.0                              cheap! cheap! cheap!!      0 NaN
# 5  0.0                                       use lansinoh      0 NaN
# 6  0.0                                    snow-white bomb      0 NaN
# 7  0.0  life suckz. my mom got this huge sat preparati...      0 NaN
# 8  0.0  damn! damn! damn! it's thunder storming. rain,...      0 NaN
# 9  0.0                 away to do this revision now.. bye      0 NaN

# %%
data=data.sample(frac=1)
data.head(10)
# Out:
#       0                      god i hate waiting around #fb  class    1
# 47  0.0  buy this dvd if your desperate to look at half...      0  NaN
# 14  NaN                                                NaN      1  1.0
# 41  0.0  just woke up from my nap, i can't believe i mi...      0  NaN
# 4   0.0                              cheap! cheap! cheap!!      0  NaN
# 22  0.0  excessive speed kills- especially in bach's ca...      0  NaN
# 23  NaN                                                NaN      1  1.0
# 15  0.0                do not buy the mr. coffee ft series      0  NaN
# 46  NaN                                                NaN      1  1.0
# 5   NaN                                                NaN      1  1.0
# 52  NaN                                                NaN      1  1.0

# %%
data.isnull().sum()
# Out:
# 0                                59
# god i hate waiting around #fb    59
# class                             0
# 1                                60
# dtype: int64

# %%
def filtering(data):
    text=data.lower()
    text=re.sub('\[.*?\]','',text)
    text=re.sub("\\W"," ",text)
    text=re.sub('https?://\s+|www\.S+','',text)
    text=re.sub('<.*?>+','',text)
    text=re.sub('[%s]'% re.escape(string.punctuation),'',text)
    text=re.sub('\w*\d\w*','',text)
    return text

# %%
import pandas as pd #for importing dataset
import numpy as nm #for doing mathematical operations
from sklearn.model_selection import train_test_split as ttp #to break dataset for training and testing
from sklearn.metrics import classification_report # to generate classification report
import re #for data cleaning purpose
import string #to deal with text data
import matplotlib.pyplot as plt #for visualizing dataset

# %%
df=pd.read_csv("/content/apple.xlsx.csv")

# %%
good_quality_apples=df[df['Quality']=='good']
bad_quality_apples=df[df['Quality']=='bad']

# %%
good_quality_apples["class"]=0
bad_quality_apples["class"]=1
# Out:
# <ipython-input-4-12389accdbdc>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   good_quality_apples["class"]=0
# <ipython-input-4-12389accdbdc>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bad_quality_apples["class"]=1

# %%
good_quality_apples.head(5)
# Out:
#    A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0     0 -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1     1 -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 3     3 -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4     4  1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
# 6     6  1.331606  1.635956   0.875974    -1.677798   3.106344 -1.847417
#
#     Acidity Quality  class
# 0 -0.491590    good      0
# 1 -0.722809    good      0
# 3  0.790723    good      0
# 4  0.501984    good      0
# 6  2.414171    good      0

# %%
bad_quality_apples.head(5)
# Out:
#     A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 2      2 -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 5      5 -3.425400 -1.409082  -1.913511    -0.555775  -3.853071  1.914616
# 8      8 -3.867632 -3.734514   0.986429    -1.207655   2.292873  4.080921
# 9      9 -0.727983 -0.442820  -4.092223     0.597513   0.393714  1.620857
# 10    10 -2.699336 -1.329507  -1.418507    -0.625546   2.371074  3.403165
#
#      Acidity Quality  class
# 2   2.621636     bad      1
# 5  -2.981523     bad      1
# 8  -4.871905     bad      1
# 9   2.185608     bad      1
# 10 -2.810808     bad      1

# %%
good_quality_apples.shape,bad_quality_apples.shape
# Out:
# ((2004, 10), (1996, 10))

# %%
good_quality_apples_manual_testing = good_quality_apples.tail(10)
for i in range(1996,1996,-1):
    good_quality_apples.drop([i],axis=0, inplace=True)#removing those 10 values from original dataset

bad_quality_apples_manual_testing = bad_quality_apples.tail(10)
for i in range(1996,1996,-1):
    good_quality_apples.drop([i],axis=0, inplace=True)#removing those 10 values from original dataset

# %%
data_manual_testing = pd.concat([bad_quality_apples_manual_testing, good_quality_apples_manual_testing], axis=0)
data_manual_testing.to_csv("manual_testing.csv ")

# %%
data_merge = pd.concat([bad_quality_apples,good_quality_apples],axis=0)
data_merge.head(10)#displaying first 10 values after above operation
# Out:
#     A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 2      2 -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 5      5 -3.425400 -1.409082  -1.913511    -0.555775  -3.853071  1.914616
# 8      8 -3.867632 -3.734514   0.986429    -1.207655   2.292873  4.080921
# 9      9 -0.727983 -0.442820  -4.092223     0.597513   0.393714  1.620857
# 10    10 -2.699336 -1.329507  -1.418507    -0.625546   2.371074  3.403165
# 12    12 -0.170812 -1.867271  -1.771845     2.413155  -3.094555 -0.624884
# 16    16 -1.468952 -1.950360  -2.214373     0.909759   2.864449  3.965956
# 18    18 -0.302364  1.724396  -2.442337     3.465108   0.449792 -0.074362
# 20    20 -2.334590 -2.943709  -3.452628     0.762392   4.076462  6.346445
# 22    22 -2.423946 -0.698501   0.146030     0.630106   2.990561  0.779473
#
#      Acidity Quality  class
# 2   2.621636     bad      1
# 5  -2.981523     bad      1
# 8  -4.871905     bad      1
# 9   2.185608     bad      1
# 10 -2.810808     bad      1
# 12 -2.076114     bad      1
# 16 -0.558209     bad      1
# 18  2.493782     bad      1
# 20  0.726776     bad      1
# 22  3.184188     bad      1

# %%
print(data_merge.groupby(['Weight'])['Sweetness'].count())
data_merge.groupby(['Weight'])['Sweetness'].count().plot(kind="bar")
plt.title("weight vs sweetness",size=20)
plt.xlabel("weight",size=20)
plt.ylabel("sweetness",size=20)
plt.show()
# Out:
# Weight
# -7.149848    1
# -6.581590    1
# -6.556685    1
# -6.428075    1
# -6.235107    1
#             ..
#  4.369571    1
#  4.738227    1
#  5.014002    1
#  5.149000    1
#  5.790714    1
# Name: Sweetness, Length: 4000, dtype: int64

# %%
print(data_merge.groupby(['class'])['Sweetness'].count())
print("0 = bad quality apples \n1 = good quality papples")
data_merge.groupby(['class'])['Sweetness'].count().plot(kind="pie")
plt.title("bad and good quality apples",size=20)
plt.show()
# Out:
# class
# 0    2004
# 1    1996
# Name: Sweetness, dtype: int64
# 0 = bad quality apples
# 1 = good quality papples

# %%
data = data_merge.drop(["Size","Weight","Quality","Crunchiness","Juiciness","Ripeness","Acidity","Acidity"], axis=1)
data.head(10) #displaying remaining dataset
# Out:
#     A_id  Sweetness  class
# 2      2  -1.738429      1
# 5      5  -1.913511      1
# 8      8   0.986429      1
# 9      9  -4.092223      1
# 10    10  -1.418507      1
# 12    12  -1.771845      1
# 16    16  -2.214373      1
# 18    18  -2.442337      1
# 20    20  -3.452628      1
# 22    22   0.146030      1

# %%
data=data.sample(frac=1)
data.head(10)
# Out:
#       A_id  Sweetness  class
# 383    383  -0.506153      0
# 2986  2986   1.709090      0
# 1243  1243   1.073350      0
# 3469  3469  -2.636059      1
# 3855  3855   1.107567      1
# 3331  3331  -0.525712      0
# 2608  2608  -1.195250      1
# 809    809  -0.827722      0
# 2232  2232  -3.942249      1
# 1992  1992   0.870952      0

# %%
data.isnull().sum()
# Out:
# A_id         0
# Sweetness    0
# class        0
# dtype: int64

# %%
x=data["Sweetness"]
y=data["class"]

# %%
x_train,x_test,y_train,y_test=ttp(x,y,test_size=0.25,random_state=0)
